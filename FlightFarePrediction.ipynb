# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = '/content/Data_Train.xlsx'
df=pd.read_excel(file_path)
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df.shape
# Out:
# (10683, 11)

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
categorical=df.select_dtypes(include='object')
categorical
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
import missingno as msno
msno.bar(df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=df.dropna()

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
data.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %%
def changetodatetime(df,column):
  df[column]=pd.to_datetime(df[column])

# %%
for i in ['Date_of_Journey','Dep_Time','Arrival_Time']:
  changetodatetime(data,i)
# Out:
# <ipython-input-159-06eeb98748c3>:2: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df[column]=pd.to_datetime(df[column])
# <ipython-input-159-06eeb98748c3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column]=pd.to_datetime(df[column])
# <ipython-input-159-06eeb98748c3>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[column]=pd.to_datetime(df[column])
# <ipython-input-159-06eeb98748c3>:2: SettingWithCopyWarning:
# ...

# %%
data.dtypes
# Out:
# Airline                    object
# Date_of_Journey    datetime64[ns]
# Source                     object
# Destination                object
# Route                      object
# Dep_Time           datetime64[ns]
# Arrival_Time       datetime64[ns]
# Duration                   object
# Total_Stops                object
# Additional_Info            object
# Price                       int64
# dtype: object

# %%
data['journey_day']=data['Date_of_Journey'].dt.day
data['journey_month']=data['Date_of_Journey'].dt.month
# Out:
# <ipython-input-162-0abd2eb9f8f8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['journey_day']=data['Date_of_Journey'].dt.day
# <ipython-input-162-0abd2eb9f8f8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['journey_month']=data['Date_of_Journey'].dt.month

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2024-12-08 22:20:00 2024-03-22 01:10:00   2h 50m    non-stop
# 1 2024-12-08 05:50:00 2024-12-08 13:15:00   7h 25m     2 stops
# 2 2024-12-08 09:25:00 2024-06-10 04:25:00      19h     2 stops
# 3 2024-12-08 18:05:00 2024-12-08 23:30:00   5h 25m      1 stop
# 4 2024-12-08 16:50:00 2024-12-08 21:35:00   4h 45m      1 stop
#
#   Additional_Info  Price  journey_day  journey_month
# 0         No info   3897           24              3
# ...

# %%
data.drop('Date_of_Journey',axis=1)
# Out:
#            Airline    Source Destination                  Route  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL
# ...            ...       ...         ...                    ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR
# 10679    Air India   Kolkata    Banglore              CCU → BLR
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL
# 10681      Vistara  Banglore   New Delhi              BLR → DEL
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK
#
#                  Dep_Time        Arrival_Time Duration Total_Stops  \
# 0     2024-12-08 22:20:00 2024-03-22 01:10:00   2h 50m    non-stop
# ...

# %%
def extract_hour(df,column):
  df[column+'_hour']=df[column].dt.hour

# %%
def extract_min(df,column):
  df[column+'_min']=df[column].dt.minute

# %%
def drop_column(df,column):
  df.drop(column,axis=1,inplace=True)

# %%
extract_hour(data,'Dep_Time')
extract_min(data,'Dep_Time')
drop_column(data,'Dep_Time')
# Out:
# <ipython-input-165-59dc89d1bc0c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column+'_hour']=df[column].dt.hour
# <ipython-input-166-9003c275df5d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column+'_min']=df[column].dt.minute
# <ipython-input-167-e400a014d1f7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi
# 1        Air India      2019-05-01   Kolkata    Banglore
# 2      Jet Airways      2019-06-09     Delhi      Cochin
# 3           IndiGo      2019-05-12   Kolkata    Banglore
# 4           IndiGo      2019-03-01  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia      2019-04-09   Kolkata    Banglore
# 10679    Air India      2019-04-27   Kolkata    Banglore
# 10680  Jet Airways      2019-04-27  Banglore       Delhi
# 10681      Vistara      2019-03-01  Banglore   New Delhi
# 10682    Air India      2019-05-09     Delhi      Cochin
#
#                        Route        Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL 2024-03-22 01:10:00   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR 2024-12-08 13:15:00   7h 25m     2 stops
# ...

# %%
extract_hour(data,'Arrival_Time')
extract_min(data,'Arrival_Time')
drop_column(data,'Arrival_Time')
# Out:
# <ipython-input-165-59dc89d1bc0c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column+'_hour']=df[column].dt.hour
# <ipython-input-166-9003c275df5d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column+'_min']=df[column].dt.minute
# <ipython-input-167-e400a014d1f7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi
# 1        Air India      2019-05-01   Kolkata    Banglore
# 2      Jet Airways      2019-06-09     Delhi      Cochin
# 3           IndiGo      2019-05-12   Kolkata    Banglore
# 4           IndiGo      2019-03-01  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia      2019-04-09   Kolkata    Banglore
# 10679    Air India      2019-04-27   Kolkata    Banglore
# 10680  Jet Airways      2019-04-27  Banglore       Delhi
# 10681      Vistara      2019-03-01  Banglore   New Delhi
# 10682    Air India      2019-05-09     Delhi      Cochin
#
#                        Route Duration Total_Stops Additional_Info  Price  \
# 0                  BLR → DEL   2h 50m    non-stop         No info   3897
# 1      CCU → IXR → BBI → BLR   7h 25m     2 stops         No info   7662
# ...

# %%
data.dtypes
# Out:
# Airline                      object
# Date_of_Journey      datetime64[ns]
# Source                       object
# Destination                  object
# Route                        object
# Duration                     object
# Total_Stops                  object
# Additional_Info              object
# Price                         int64
# journey_day                   int32
# journey_month                 int32
# Dep_Time_hour                 int32
# Dep_Time_min                  int32
# Arrival_Time_hour             int32
# Arrival_Time_min              int32
# dtype: object

# %%
dura=list(data['Duration'])
for i in range(len(dura)):
  if len(dura[i].split())!=2:
    if 'h' in dura[i]:
      dura[i]=dura[i].strip()+' 0m'
    else:
      dura[i]='0h '+dura[i]

# %%
data['Duration']=dura
# Out:
# <ipython-input-174-eb132eb6e06e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Duration']=dura

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi
# 1        Air India      2019-05-01   Kolkata    Banglore
# 2      Jet Airways      2019-06-09     Delhi      Cochin
# 3           IndiGo      2019-05-12   Kolkata    Banglore
# 4           IndiGo      2019-03-01  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia      2019-04-09   Kolkata    Banglore
# 10679    Air India      2019-04-27   Kolkata    Banglore
# 10680  Jet Airways      2019-04-27  Banglore       Delhi
# 10681      Vistara      2019-03-01  Banglore   New Delhi
# 10682    Air India      2019-05-09     Delhi      Cochin
#
#                        Route Duration Total_Stops Additional_Info  Price  \
# 0                  BLR → DEL   2h 50m    non-stop         No info   3897
# 1      CCU → IXR → BBI → BLR   7h 25m     2 stops         No info   7662
# ...

# %%
data.dtypes
# Out:
# Airline                      object
# Date_of_Journey      datetime64[ns]
# Source                       object
# Destination                  object
# Route                        object
# Duration                     object
# Total_Stops                  object
# Additional_Info              object
# Price                         int64
# journey_day                   int32
# journey_month                 int32
# Dep_Time_hour                 int32
# Dep_Time_min                  int32
# Arrival_Time_hour             int32
# Arrival_Time_min              int32
# dtype: object

# %%
def hour(x):
  return x.split(' ')[0][0:-1]

# %%
def min(x):
  return x.split(' ')[1][0:-1]

# %%
data['Duration_hours']=data['Duration'].apply(hour)
data['Duration_min']=data['Duration'].apply(min)
# Out:
# <ipython-input-179-97077239a372>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Duration_hours']=data['Duration'].apply(hour)
# <ipython-input-179-97077239a372>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Duration_min']=data['Duration'].apply(min)

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi
# 1        Air India      2019-05-01   Kolkata    Banglore
# 2      Jet Airways      2019-06-09     Delhi      Cochin
# 3           IndiGo      2019-05-12   Kolkata    Banglore
# 4           IndiGo      2019-03-01  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia      2019-04-09   Kolkata    Banglore
# 10679    Air India      2019-04-27   Kolkata    Banglore
# 10680  Jet Airways      2019-04-27  Banglore       Delhi
# 10681      Vistara      2019-03-01  Banglore   New Delhi
# 10682    Air India      2019-05-09     Delhi      Cochin
#
#                        Route Duration Total_Stops Additional_Info  Price  \
# 0                  BLR → DEL   2h 50m    non-stop         No info   3897
# 1      CCU → IXR → BBI → BLR   7h 25m     2 stops         No info   7662
# ...

# %%
data.drop('Duration',axis=1,inplace=True)
# Out:
# <ipython-input-181-756ce56896a0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop('Duration',axis=1,inplace=True)

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#   Total_Stops Additional_Info  Price  journey_day  journey_month  \
# 0    non-stop         No info   3897           24              3
# 1     2 stops         No info   7662            1              5
# 2     2 stops         No info  13882            9              6
# 3      1 stop         No info   6218           12              5
# 4      1 stop         No info  13302            1              3
#
#    Dep_Time_hour  Dep_Time_min  Arrival_Time_hour  Arrival_Time_min  \
# ...

# %%
data.dtypes
# Out:
# Airline                      object
# Date_of_Journey      datetime64[ns]
# Source                       object
# Destination                  object
# Route                        object
# Total_Stops                  object
# Additional_Info              object
# Price                         int64
# journey_day                   int32
# journey_month                 int32
# Dep_Time_hour                 int32
# Dep_Time_min                  int32
# Arrival_Time_hour             int32
# Arrival_Time_min              int32
# Duration_hours               object
# Duration_min                 object
# dtype: object

# %%
data['Duration_hours'] = data['Duration_hours'].astype('int64')
data['Duration_min'] = data['Duration_min'].astype('int64')
# Out:
# <ipython-input-184-0732716bc250>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Duration_hours'] = data['Duration_hours'].astype('int64')
# <ipython-input-184-0732716bc250>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Duration_min'] = data['Duration_min'].astype('int64')

# %%
data.dtypes
# Out:
# Airline                      object
# Date_of_Journey      datetime64[ns]
# Source                       object
# Destination                  object
# Route                        object
# Total_Stops                  object
# Additional_Info              object
# Price                         int64
# journey_day                   int32
# journey_month                 int32
# Dep_Time_hour                 int32
# Dep_Time_min                  int32
# Arrival_Time_hour             int32
# Arrival_Time_min              int32
# Duration_hours                int64
# Duration_min                  int64
# dtype: object

# %%
data.drop('Date_of_Journey',axis=1,inplace=True)
# Out:
# <ipython-input-186-6f0a9237041e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop('Date_of_Journey',axis=1,inplace=True)

# %%
categorical_col=[column for column in data.columns if data[column].dtype=='object']
categorical_col
# Out:
# ['Airline', 'Source', 'Destination', 'Route', 'Total_Stops', 'Additional_Info']

# %%
categorical=data[categorical_col]
categorical
# Out:
#            Airline    Source Destination                  Route Total_Stops  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
# ...            ...       ...         ...                    ...         ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    non-stop
# 10679    Air India   Kolkata    Banglore              CCU → BLR    non-stop
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    non-stop
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    non-stop
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK     2 stops
#
#       Additional_Info
# 0             No info
# ...

# %%
plt.figure(figsize=(30,10))

sns.barplot(x='Airline',y='Price',data=data)
# Out:
# <Axes: xlabel='Airline', ylabel='Price'>

# %%
plt.figure(figsize=(30,10))

sns.barplot(x='Total_Stops',y='Price',data=data)
# Out:
# <Axes: xlabel='Total_Stops', ylabel='Price'>

# %%
plt.figure(figsize=(30,10))

sns.barplot(x='Source',y='Price',data=data)
# Out:
# <Axes: xlabel='Source', ylabel='Price'>

# %%
plt.figure(figsize=(30,10))

sns.barplot(x='Destination',y='Price',data=data)
# Out:
# <Axes: xlabel='Destination', ylabel='Price'>

# %%
data
# Out:
#            Airline    Source Destination                  Route Total_Stops  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
# ...            ...       ...         ...                    ...         ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    non-stop
# 10679    Air India   Kolkata    Banglore              CCU → BLR    non-stop
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    non-stop
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    non-stop
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK     2 stops
#
# ...

# %%
categorical['Route1']=categorical['Route'].str.split('→').str[0]
categorical['Route2']=categorical['Route'].str.split('→').str[1]
categorical['Route3']=categorical['Route'].str.split('→').str[2]
categorical['Route4']=categorical['Route'].str.split('→').str[3]
categorical['Route5']=categorical['Route'].str.split('→').str[4]
# Out:
# <ipython-input-194-120f0361f136>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical['Route1']=categorical['Route'].str.split('→').str[0]
# <ipython-input-194-120f0361f136>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical['Route2']=categorical['Route'].str.split('→').str[1]
# <ipython-input-194-120f0361f136>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
categorical.isnull().sum()
# Out:
# Airline                0
# Source                 0
# Destination            0
# Route                  0
# Total_Stops            0
# Additional_Info        0
# Route1                 0
# Route2                 0
# Route3              3491
# Route4              9116
# Route5             10636
# dtype: int64

# %%
data.drop('Route',axis=1,inplace=True)
# Out:
# <ipython-input-196-6a86620e160f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop('Route',axis=1,inplace=True)

# %%
for i in ['Route1','Route2','Route3','Route4','Route5']:
  categorical[i].fillna('None',inplace=True)
# Out:
# <ipython-input-197-d96741bedf3e>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   categorical[i].fillna('None',inplace=True)
# <ipython-input-197-d96741bedf3e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical[i].fillna('None',inplace=True)

# %%
categorical.isnull().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Route              0
# Total_Stops        0
# Additional_Info    0
# Route1             0
# Route2             0
# Route3             0
# Route4             0
# Route5             0
# dtype: int64

# %%
data['Route1']=categorical['Route1']
data['Route2']=categorical['Route2']
data['Route3']=categorical['Route3']
data['Route4']=categorical['Route4']
data['Route5']=categorical['Route5']
# Out:
# <ipython-input-199-ed366726ce86>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Route1']=categorical['Route1']
# <ipython-input-199-ed366726ce86>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Route2']=categorical['Route2']
# <ipython-input-199-ed366726ce86>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data
# Out:
#            Airline    Source Destination Total_Stops Additional_Info  Price  \
# 0           IndiGo  Banglore   New Delhi    non-stop         No info   3897
# 1        Air India   Kolkata    Banglore     2 stops         No info   7662
# 2      Jet Airways     Delhi      Cochin     2 stops         No info  13882
# 3           IndiGo   Kolkata    Banglore      1 stop         No info   6218
# 4           IndiGo  Banglore   New Delhi      1 stop         No info  13302
# ...            ...       ...         ...         ...             ...    ...
# 10678     Air Asia   Kolkata    Banglore    non-stop         No info   4107
# 10679    Air India   Kolkata    Banglore    non-stop         No info   4145
# 10680  Jet Airways  Banglore       Delhi    non-stop         No info   7229
# 10681      Vistara  Banglore   New Delhi    non-stop         No info  12648
# 10682    Air India     Delhi      Cochin     2 stops         No info  11753
#
# ...

# %%
# Check if 'Route' column exists before dropping
if 'Route' in data.columns:
  data.drop('Route', axis=1, inplace=True)

# %%
categorical
# Out:
#            Airline    Source Destination                  Route Total_Stops  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
# ...            ...       ...         ...                    ...         ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    non-stop
# 10679    Air India   Kolkata    Banglore              CCU → BLR    non-stop
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    non-stop
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    non-stop
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK     2 stops
#
#       Additional_Info Route1 Route2 Route3 Route4 Route5
# ...

# %%
categorical.drop('Route',axis=1,inplace=True)
# Out:
# <ipython-input-205-355abec33017>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical.drop('Route',axis=1,inplace=True)

# %%
categorical
# Out:
#            Airline    Source Destination Total_Stops Additional_Info Route1  \
# 0           IndiGo  Banglore   New Delhi    non-stop         No info   BLR
# 1        Air India   Kolkata    Banglore     2 stops         No info   CCU
# 2      Jet Airways     Delhi      Cochin     2 stops         No info   DEL
# 3           IndiGo   Kolkata    Banglore      1 stop         No info   CCU
# 4           IndiGo  Banglore   New Delhi      1 stop         No info   BLR
# ...            ...       ...         ...         ...             ...    ...
# 10678     Air Asia   Kolkata    Banglore    non-stop         No info   CCU
# 10679    Air India   Kolkata    Banglore    non-stop         No info   CCU
# 10680  Jet Airways  Banglore       Delhi    non-stop         No info   BLR
# 10681      Vistara  Banglore   New Delhi    non-stop         No info   BLR
# 10682    Air India     Delhi      Cochin     2 stops         No info   DEL
#
#       Route2 Route3 Route4 Route5
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in ['Route1','Route2','Route3','Route4','Route5']:
  categorical[i]=le.fit_transform(categorical[i])
# Out:
# <ipython-input-207-292c5c87b77e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical[i]=le.fit_transform(categorical[i])
# <ipython-input-207-292c5c87b77e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical[i]=le.fit_transform(categorical[i])
# <ipython-input-207-292c5c87b77e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
categorical.head()
# Out:
#        Airline    Source Destination Total_Stops Additional_Info  Route1  \
# 0       IndiGo  Banglore   New Delhi    non-stop         No info       0
# 1    Air India   Kolkata    Banglore     2 stops         No info       2
# 2  Jet Airways     Delhi      Cochin     2 stops         No info       3
# 3       IndiGo   Kolkata    Banglore      1 stop         No info       2
# 4       IndiGo  Banglore   New Delhi      1 stop         No info       0
#
#    Route2  Route3  Route4  Route5
# 0      13      29      13       5
# 1      25       1       3       5
# 2      32       4       5       5
# 3      34       3      13       5
# 4      34       8      13       5

# %%
Airline=pd.get_dummies(categorical['Airline'],drop_first=True)
source=pd.get_dummies(categorical['Source'],drop_first=True)
destination=pd.get_dummies(categorical['Destination'],drop_first=True)

# %%
categorical.drop('Source',axis=1,inplace=True)
categorical.drop('Destination',axis=1,inplace=True)
categorical.drop('Airline',axis=1,inplace=True)
# Out:
# <ipython-input-210-091ede89b08b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical.drop('Source',axis=1,inplace=True)
# <ipython-input-210-091ede89b08b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical.drop('Destination',axis=1,inplace=True)
# <ipython-input-210-091ede89b08b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical.drop('Airline',axis=1,inplace=True)

# %%
for i in ['Airline', 'Source', 'Destination']:
    #Fit_transform on 'data' instead of 'df' to ensure matching lengths
    data[i]=le.fit_transform(data[i])
# Out:
# <ipython-input-211-4d2570ada812>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i]=le.fit_transform(data[i])
# <ipython-input-211-4d2570ada812>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i]=le.fit_transform(data[i])
# <ipython-input-211-4d2570ada812>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
cont_col=[column for column in data.columns if data[column].dtype!='object']
cont_col
# Out:
# ['Airline',
#  'Source',
#  'Destination',
#  'Price',
#  'journey_day',
#  'journey_month',
#  'Dep_Time_hour',
#  'Dep_Time_min',
#  'Arrival_Time_hour',
#  'Arrival_Time_min',
#  'Duration_hours',
#  'Duration_min']

# %%
final_df=pd.concat([categorical,Airline,source,destination,data[cont_col]],axis=1)

# %%
final_df.dtypes
# Out:
# Total_Stops                          object
# Additional_Info                      object
# Route1                                int64
# Route2                                int64
# Route3                                int64
# Route4                                int64
# Route5                                int64
# Air India                              bool
# GoAir                                  bool
# IndiGo                                 bool
# Jet Airways                            bool
# Jet Airways Business                   bool
# Multiple carriers                      bool
# Multiple carriers Premium economy      bool
# SpiceJet                               bool
# Trujet                                 bool
# Vistara                                bool
# Vistara Premium economy                bool
# Chennai                                bool
# Delhi                                  bool
# Kolkata                                bool
# ...

# %%
data['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],
#       dtype=object)

# %%
dict={'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4}
final_df['Total_Stops']=final_df['Total_Stops'].map(dict)

# %%
final_df
# Out:
#        Total_Stops Additional_Info  Route1  Route2  Route3  Route4  Route5  \
# 0                0         No info       0      13      29      13       5
# 1                2         No info       2      25       1       3       5
# 2                2         No info       3      32       4       5       5
# 3                1         No info       2      34       3      13       5
# 4                1         No info       0      34       8      13       5
# ...            ...             ...     ...     ...     ...     ...     ...
# 10678            0         No info       2       5      29      13       5
# 10679            0         No info       2       5      29      13       5
# 10680            0         No info       0      13      29      13       5
# 10681            0         No info       0      13      29      13       5
# 10682            2         No info       3      16       4       5       5
#
# ...

# %%
final_df.dtypes
# Out:
# Total_Stops                           int64
# Additional_Info                      object
# Route1                                int64
# Route2                                int64
# Route3                                int64
# Route4                                int64
# Route5                                int64
# Air India                              bool
# GoAir                                  bool
# IndiGo                                 bool
# Jet Airways                            bool
# Jet Airways Business                   bool
# Multiple carriers                      bool
# Multiple carriers Premium economy      bool
# SpiceJet                               bool
# Trujet                                 bool
# Vistara                                bool
# Vistara Premium economy                bool
# Chennai                                bool
# Delhi                                  bool
# Kolkata                                bool
# ...

# %%
final_df.drop('Additional_Info',axis=1,inplace=True)

# %%
final_df.head()
# Out:
#    Total_Stops  Route1  Route2  Route3  Route4  Route5  Air India  GoAir  \
# 0            0       0      13      29      13       5      False  False
# 1            2       2      25       1       3       5       True  False
# 2            2       3      32       4       5       5      False  False
# 3            1       2      34       3      13       5      False  False
# 4            1       0      34       8      13       5      False  False
#
#    IndiGo  Jet Airways  ...  Destination  Price  journey_day  journey_month  \
# 0    True        False  ...            5   3897           24              3
# 1   False        False  ...            0   7662            1              5
# 2   False         True  ...            1  13882            9              6
# 3    True        False  ...            0   6218           12              5
# 4    True        False  ...            5  13302            1              3
#
# ...

# %%
X = final_df.drop('Price', axis=1)  # Features
y = final_df['Price']  # Target variable


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=123)

# %%
rf=RandomForestRegressor()
rf_random=RandomizedSearchCV(estimator=rf,param_distributions=randomgrid,cv=3,verbose=2,n_jobs=-1,)

rf_random.fit(X_train,y_train)

# best parameter
rf_random.best_params_
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# {'n_estimators': 220, 'max_features': 'sqrt', 'max_depth': 15}

# %%
from sklearn.model_selection import RandomizedSearchCV
randomgrid= {
    'n_estimators':[100, 120, 150, 170, 200, 220],
    'max_features':['auto','sqrt'],
    'max_depth':[5,10,15,20]
}

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV

# Update randomgrid to use 'sqrt' instead of 'auto' for max_features
randomgrid = {
    'n_estimators': [100, 120, 150, 170, 200, 220],
    'max_features': ['sqrt'],  # Changed 'auto' to 'sqrt'
    'max_depth': [5, 10, 15, 20]
}

rf = RandomForestRegressor()
rf_random = RandomizedSearchCV(estimator=rf, param_distributions=randomgrid, cv=3, verbose=2, n_jobs=-1)

# Convert column names to strings before fitting
X_train.columns = X_train.columns.astype(str)  # Convert column names to strings

rf_random.fit(X_train, y_train)

# best parameter
rf_random.best_params_
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# {'n_estimators': 150, 'max_features': 'sqrt', 'max_depth': 15}

# %%
from sklearn.metrics import r2_score
X_test.columns = X_test.columns.astype(str)

prediction = rf_random.predict(X_test)
r2_score(y_test, prediction)
# Out:
# 0.852897568096076
